# %%
import sklearn 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# ### Reading CSV file and viewing first 10 rows

# %%
advert_df = pd.read_csv('advertising.csv')
advert_df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
advert_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# ### Cleaning up the data

# %%
advert_df = advert_df.replace('?',np.NaN)
advert_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
advert_df.head(50)
# Out:
#        TV  Radio  Newspaper  Sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3   12.0
# 3   151.5   41.3       58.5   16.5
# 4   180.8   10.8       58.4   17.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   15.6
# 10   66.1    5.8       24.2   12.6
# 11  214.7   24.0        4.0   17.4
# 12   23.8   35.1       65.9    9.2
# 13   97.5    7.6        7.2   13.7
# 14  204.1   32.9       46.0   19.0
# 15  195.4   47.7       52.9   22.4
# 16   67.8   36.6      114.0   12.5
# 17  281.4   39.6       55.8   24.4
# 18   69.2   20.5       18.3   11.3
# 19  147.3   23.9       19.1   14.6
# 20  218.4   27.7       53.4   18.0
# 21  237.4    5.1       23.5   17.5
# 22   13.2   15.9       49.6    5.6
# 23  228.3   16.9       26.2   20.5
# 24   62.3   12.6       18.3    9.7
# 25  262.9    3.5       19.5   17.0
# ...

# %%
advert_df.tail(50)
# Out:
#         TV  Radio  Newspaper  Sales
# 150  280.7   13.9       37.0   16.1
# 151  121.0    8.4       48.7   11.6
# 152  197.6   23.3       14.2   16.6
# 153  171.3   39.7       37.7   16.0
# 154  187.8   21.1        9.5   20.6
# 155    4.1   11.6        5.7    3.2
# 156   93.9   43.5       50.5   15.3
# 157  149.8    1.3       24.3   10.1
# 158   11.7   36.9       45.2    7.3
# 159  131.7   18.4       34.6   12.9
# 160  172.5   18.1       30.7   16.4
# 161   85.7   35.8       49.3   13.3
# 162  188.4   18.1       25.6   19.9
# 163  163.5   36.8        7.4   18.0
# 164  117.2   14.7        5.4   11.9
# 165  234.5    3.4       84.8   16.9
# 166   17.9   37.6       21.6    8.0
# 167  206.8    5.2       19.4   17.2
# 168  215.4   23.6       57.6   17.1
# 169  284.3   10.6        6.4   20.0
# 170   50.0   11.6       18.4    8.4
# 171  164.5   20.9       47.4   17.5
# 172   19.6   20.1       17.0    7.6
# 173  168.4    7.1       12.8   16.7
# 174  222.4    3.4       13.1   16.5
# ...

# %%
advert_df =advert_df.replace('?',np.NaN)
advert_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Notice the csv file is a clean file type the reason we still have our total number of rows the same

# %%
advert_df = advert_df.dropna()
advert_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
advert_df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ### Testing Phase

# %%
from sklearn.model_selection import train_test_split

X = advert_df[['TV']]
Y = advert_df['Sales']

X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size = 0.2)

# %%
X_train.sample(5)
# Out:
#         TV
# 32    97.2
# 128  220.3
# 99   135.2
# 25   262.9
# 127   80.2

# %%
Y_train.sample(5)
# Out:
# 187    17.3
# 6      11.8
# 101    23.8
# 23     20.5
# 41     17.1
# Name: Sales, dtype: float64

# %% [markdown]
# ### Training the Algorithm, we have to import LinearRegression

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(X_train,Y_train)

# %%
('Training score: ', linear_model.score(X_train, Y_train))
# Out:
# ('Training score: ', 0.8049611775406511)

# %% [markdown]
# ### We can then predict variables for the testing, notice we have to import r2 from sklearn.metrics

# %%
Y_pred = linear_model.predict(X_test) #y_test

# %%
from sklearn.metrics import r2_score
print('Testing score: ', r2_score(Y_test,Y_pred))
# Out:
# Testing score:  0.8357235853385216

# %%
fig, ax = plt.subplots(figsize = (12,8))

plt.scatter(X_test,Y_test)
plt.plot(X_test, Y_pred, color ='r')

plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %% [raw]
# The graph above shows the prediction line red cut across the scatter graph which means the prediction is near accurate.
# Hence this shows the machine has learn very well and can be deployed for use in subsequent work.

# %% [markdown]
# ### Linear Regression with multiple features

# %%
    X = advert_df[['TV','Radio','Newspaper']]
    Y = advert_df['Sales']
    
    X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size = 0.2)

# %%
linear_model =LinearRegression(normalize=True).fit(X_train, Y_train)

# %%
print('training score: ',linear_model.score(X_train, Y_train))
# Out:
# training score:  0.909435057661765

# %%
Y_pred = linear_model.predict(X_test) #Y_test

# %%
print('testing score: ', r2_score(Y_test, Y_pred))
# Out:
# testing score:  0.8677005778997705

# %%
plt.figure(figsize = (20,10))

plt.plot (Y_pred, label= 'predicted')
plt.plot (Y_test.values, label = 'actual')

plt.ylabel('sales')

plt.legend()
plt.show()

# %% [raw]
# The prediction is also near accurate, hence the algorithm is a perfect one and can be deployed for use
